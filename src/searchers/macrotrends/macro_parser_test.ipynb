# %%
import pandas as pd
import numpy as np
import os
from pathlib import Path
from src.base_config import FILEPATH
import json
pd.set_option("display.max_columns", 200)

# %%
with open(os.path.join(FILEPATH, "macro_all_stocks_analysis.json"), "r") as f:
    data = json.load(f)

# %%
df = pd.DataFrame(data)

# %%
df.shape
# Out:
# (5499, 69)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# price_50y               5416
# price_40y               5202
# price_30y               4470
# price_20y               3676
# price_10y               2879
#                         ...
# zacks_oper_margin_q0       0
# avg_vol_20d                0
# pe_ratio_12m               0
# net_margin_q0              0
# name_link                  0
# Length: 69, dtype: int64

# %%
row = df.sample(1)

# %%
row.columns
# Out:
# Index(['eps_amt_diff_surp_qr0', 'price_50y', 'price_40y', 'price_20ma',
#        'price_30y', 'free_float', 'eps_act_fr0', 'eps_mean_est_fr2',
#        'eps_mean_est_fr1', 'eps_pct_diff_surp_qr0', 'ticker', 'eps_act_qr0',
#        'eps_mean_est_qr0', 'diluted_eps_net_4q', 'iad', 'comp_name',
#        'comp_name_2', 'zacks_x_ind_desc', 'zacks_x_sector_desc',
#        'zacks_m_ind_desc', 'emp_cnt', 'exchange', 'country_code',
#        'tot_revenue_f0', 'net_income_f0', 'beta', 'price_1w', 'market_val',
#        'zacks_oper_margin_q0', 'avg_vol_20d', 'pe_ratio_12m', 'price_1m',
#        'net_margin_q0', 'pre_tax_margin_q0', 'div_yield', 'price_3m',
#        'forward_pe_ratio', 'held_by_insiders_pct', 'price_6m', 'last_close',
#        'held_by_institutions_pct', 'peg_ratio', 'cons_recom_curr',
#        'price_cash', 'price_1y', 'price_ytd', 'eps_growth_qoq', 'price_book',
#        'price_per_sales', 'dividend_payout_ratio', 'price_3y', 'price_5y',
#        'sales_growth_qoq', 'debt_to_comm_equ_q0', 'price_10y', 'roa_q0',
#        'roe_q0', 'price_20y', 'curr_ratio_q0', 'fifty_two_week',
#        'quick_ratio_q0', 'inv_turnover_q0', 'price_50ma', 'price_200ma',
#        'eps_growth_5y', 'sales_growth_5y', 'eps_growth_this_yr',
#        'eps_growth_next_yr', 'name_link'],
#       dtype='object')

# %%
df["ticker"].unique()
# Out:
# array(['A', 'AA', 'AACG', ..., 'ZYBT', 'ZYME', 'ZYXI'],
#       shape=(5499,), dtype=object)

# %%
def convert(entry: str):
    if not entry:
        return np.nan
    if entry.isnumeric():
        return float(entry)
    return entry

# %%
df1 = df.map(convert)
